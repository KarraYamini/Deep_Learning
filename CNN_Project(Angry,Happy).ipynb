# %% [markdown]
# #1)Problem Statement:
# The goal of this project is to classify facial expressions as Angry or Happy using deep learning.
#
# The dataset contains images of faces with two emotion categories: Angry and Happy. The images are preprocessed by applying scaling and separating the dataset into training and testing sets.
#
# A Sequential Convolutional Neural Network (CNN) model is built to learn patterns from the images and classify the emotions.

# %% [markdown]
# #2)Import Libraries:

# %%
import os

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# #3)Load Dataset:

# %%
path_angry="/content/drive/MyDrive/Angry"

# %%
path_angry
# Out:
# '/content/drive/MyDrive/Angry'

# %%
path_happy="/content/drive/MyDrive/Happy"

# %%
path_happy
# Out:
# '/content/drive/MyDrive/Happy'

# %% [markdown]
# #Fetching image names from relevant folders:

# %% [markdown]
# #Angry:

# %%
os.listdir(path_angry)
# Out:
# ['8330.jpg',
#  '8245.jpg',
#  '8272.jpg',
#  '8077.jpg',
#  '8255.jpg',
#  '824.jpg',
#  '8278.jpg',
#  '8113.jpg',
#  '8438.jpg',
#  '8051.jpg',
#  '8431.jpg',
#  '8221.jpg',
#  '8432.jpg',
#  '8413.jpg',
#  '8194.jpg',
#  '8396.jpg',
#  '8422.jpg',
#  '8253.jpg',
#  '8423.jpg',
#  '835.jpg',
#  '8069.jpg',
#  '8201.jpg',
#  '8273.jpg',
#  '8465.jpg',
#  '8289.jpg',
#  '8182.jpg',
#  '8149.jpg',
#  '8513.jpg',
#  '834.jpg',
#  '8371.jpg',
#  '8487.jpg',
#  '8160.jpg',
#  '851.jpg',
#  '7415.jpg',
#  '8412.jpg',
#  '823.jpg',
#  '8270.jpg',
#  '8320.jpg',
#  '8545.jpg',
#  '8092.jpg',
#  '8515.jpg',
#  '8519.jpg',
#  '8358.jpg',
#  '8271.jpg',
#  '8482.jpg',
#  '8500.jpg',
#  '8183.jpg',
#  '8168.jpg',
#  '8166.jpg',
#  '8472.jpg',
#  '8535.jpg',
#  '8150.jpg',
#  '8169.jpg',
#  '8323.jpg',
#  '8134.jpg',
#  '8124.jpg',
#  '8528.jpg',
#  '7491.jpg',
#  '8202.jpg',
#  '8547.jpg',
#  '850.jpg',
#  '8162.jpg',
#  '8120.jpg',
#  '8458.jpg',
#  '8286.jpg',
#  '8224.jpg',
#  '9208.jpg',
# ...

# %%
angry_image_names=os.listdir(path_angry)

# %%
len(angry_image_names)
# Out:
# 953

# %%
angry_image_names[0]
# Out:
# '8330.jpg'

# %%
path_angry
# Out:
# '/content/drive/MyDrive/Angry'

# %%
path_angry+angry_image_names[0]
# Out:
# '/content/drive/MyDrive/Angry8330.jpg'

# %%
img1 = cv2.imread(path_angry+"/"+angry_image_names[0])

# %%
img1
# Out:
# array([[[ 43,  43,  43],
#         [ 32,  32,  32],
#         [ 50,  50,  50],
#         ...,
#         [237, 237, 237],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[ 43,  43,  43],
#         [ 26,  26,  26],
#         [ 38,  38,  38],
#         ...,
#         [251, 251, 251],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[ 41,  41,  41],
#         [ 49,  49,  49],
#         [ 47,  47,  47],
#         ...,
#         [255, 255, 255],
#         [251, 251, 251],
#         [252, 252, 252]],
#
#        ...,
#
#        [[174, 174, 174],
#         [ 24,  24,  24],
#         [ 61,  61,  61],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[252, 252, 252],
#         [154, 154, 154],
#         [ 43,  43,  43],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[208, 208, 208],
#         [255, 255, 255],
#         [203, 203, 203],
# ...

# %%
plt.imshow(img1)

# %%
path_angry+angry_image_names[500]
# Out:
# '/content/drive/MyDrive/Angry29471.jpg'

# %%
img2=cv2.imread(path_angry+"/"+angry_image_names[500])

# %%
img2
# Out:
# array([[[155, 155, 155],
#         [108, 108, 108],
#         [100, 100, 100],
#         ...,
#         [106, 106, 106],
#         [104, 104, 104],
#         [ 93,  93,  93]],
#
#        [[128, 128, 128],
#         [161, 161, 161],
#         [112, 112, 112],
#         ...,
#         [ 74,  74,  74],
#         [ 73,  73,  73],
#         [ 93,  93,  93]],
#
#        [[111, 111, 111],
#         [136, 136, 136],
#         [106, 106, 106],
#         ...,
#         [ 59,  59,  59],
#         [ 60,  60,  60],
#         [ 82,  82,  82]],
#
#        ...,
#
#        [[ 43,  43,  43],
#         [  4,   4,   4],
#         [107, 107, 107],
#         ...,
#         [ 97,  97,  97],
#         [122, 122, 122],
#         [146, 146, 146]],
#
#        [[ 26,  26,  26],
#         [121, 121, 121],
#         [223, 223, 223],
#         ...,
#         [108, 108, 108],
#         [147, 147, 147],
#         [178, 178, 178]],
#
#        [[129, 129, 129],
#         [219, 219, 219],
#         [180, 180, 180],
# ...

# %%
plt.imshow(img2)

# %%
img1.shape
# Out:
# (48, 48, 3)

# %%
img2.shape
# Out:
# (48, 48, 3)

# %% [markdown]
# #Happy:

# %%
os.listdir(path_happy)
# Out:
# ['20945.jpg',
#  '21708.jpg',
#  '20745.jpg',
#  '21483.jpg',
#  '21292.jpg',
#  '21200.jpg',
#  '21027.jpg',
#  '22340.jpg',
#  '20984.jpg',
#  '20829.jpg',
#  '22056.jpg',
#  '22289.jpg',
#  '22532.jpg',
#  '22763.jpg',
#  '22671.jpg',
#  '22080.jpg',
#  '21943.jpg',
#  '21593.jpg',
#  '20547.jpg',
#  '21033.jpg',
#  '21077.jpg',
#  '20561.jpg',
#  '22604.jpg',
#  '21501.jpg',
#  '20445.jpg',
#  '22679.jpg',
#  '22138.jpg',
#  '21316.jpg',
#  '20580.jpg',
#  '22179.jpg',
#  '21098.jpg',
#  '20889.jpg',
#  '22574.jpg',
#  '210.jpg',
#  '21846.jpg',
#  '2069.jpg',
#  '21750.jpg',
#  '2182.jpg',
#  '20866.jpg',
#  '21927.jpg',
#  '22560.jpg',
#  '20857.jpg',
#  '21120.jpg',
#  '22424.jpg',
#  '21394.jpg',
#  '2231.jpg',
#  '21778.jpg',
#  '22194.jpg',
#  '22506.jpg',
#  '20941.jpg',
#  '21305.jpg',
#  '22545.jpg',
#  '21961.jpg',
#  '22154.jpg',
#  '20490.jpg',
#  '22247.jpg',
#  '21574.jpg',
#  '22395.jpg',
#  '20918.jpg',
#  '20685.jpg',
#  '2135.jpg',
#  '20972.jpg',
# ...

# %%
happy_image_names=os.listdir(path_happy)

# %%
happy_image_names
# Out:
# ['20945.jpg',
#  '21708.jpg',
#  '20745.jpg',
#  '21483.jpg',
#  '21292.jpg',
#  '21200.jpg',
#  '21027.jpg',
#  '22340.jpg',
#  '20984.jpg',
#  '20829.jpg',
#  '22056.jpg',
#  '22289.jpg',
#  '22532.jpg',
#  '22763.jpg',
#  '22671.jpg',
#  '22080.jpg',
#  '21943.jpg',
#  '21593.jpg',
#  '20547.jpg',
#  '21033.jpg',
#  '21077.jpg',
#  '20561.jpg',
#  '22604.jpg',
#  '21501.jpg',
#  '20445.jpg',
#  '22679.jpg',
#  '22138.jpg',
#  '21316.jpg',
#  '20580.jpg',
#  '22179.jpg',
#  '21098.jpg',
#  '20889.jpg',
#  '22574.jpg',
#  '210.jpg',
#  '21846.jpg',
#  '2069.jpg',
#  '21750.jpg',
#  '2182.jpg',
#  '20866.jpg',
#  '21927.jpg',
#  '22560.jpg',
#  '20857.jpg',
#  '21120.jpg',
#  '22424.jpg',
#  '21394.jpg',
#  '2231.jpg',
#  '21778.jpg',
#  '22194.jpg',
#  '22506.jpg',
#  '20941.jpg',
#  '21305.jpg',
#  '22545.jpg',
#  '21961.jpg',
#  '22154.jpg',
#  '20490.jpg',
#  '22247.jpg',
#  '21574.jpg',
#  '22395.jpg',
#  '20918.jpg',
#  '20685.jpg',
#  '2135.jpg',
#  '20972.jpg',
# ...

# %%
len(happy_image_names)
# Out:
# 3115

# %%
path_happy+"/"+happy_image_names[0]
# Out:
# '/content/drive/MyDrive/Happy/20945.jpg'

# %%
h_img1=cv2.imread(path_happy+"/"+happy_image_names[0])

# %%
h_img1
# Out:
# array([[[ 12,  12,  12],
#         [ 16,  16,  16],
#         [ 17,  17,  17],
#         ...,
#         [138, 138, 138],
#         [ 49,  49,  49],
#         [ 23,  23,  23]],
#
#        [[ 13,  13,  13],
#         [ 13,  13,  13],
#         [ 15,  15,  15],
#         ...,
#         [138, 138, 138],
#         [ 49,  49,  49],
#         [ 14,  14,  14]],
#
#        [[ 14,  14,  14],
#         [ 11,  11,  11],
#         [ 12,  12,  12],
#         ...,
#         [142, 142, 142],
#         [ 44,  44,  44],
#         [ 13,  13,  13]],
#
#        ...,
#
#        [[ 20,  20,  20],
#         [ 10,  10,  10],
#         [ 19,  19,  19],
#         ...,
#         [ 11,  11,  11],
#         [ 85,  85,  85],
#         [129, 129, 129]],
#
#        [[ 18,  18,  18],
#         [  9,   9,   9],
#         [ 18,  18,  18],
#         ...,
#         [ 14,  14,  14],
#         [ 85,  85,  85],
#         [131, 131, 131]],
#
#        [[ 19,  19,  19],
#         [  9,   9,   9],
#         [ 18,  18,  18],
# ...

# %%
plt.imshow(h_img1)

# %%
h_img2=cv2.imread(path_happy+"/"+happy_image_names[250])

# %%
h_img2
# Out:
# array([[[144, 144, 144],
#         [138, 138, 138],
#         [130, 130, 130],
#         ...,
#         [120, 120, 120],
#         [136, 136, 136],
#         [136, 136, 136]],
#
#        [[140, 140, 140],
#         [135, 135, 135],
#         [138, 138, 138],
#         ...,
#         [120, 120, 120],
#         [136, 136, 136],
#         [133, 133, 133]],
#
#        [[141, 141, 141],
#         [133, 133, 133],
#         [148, 148, 148],
#         ...,
#         [121, 121, 121],
#         [136, 136, 136],
#         [133, 133, 133]],
#
#        ...,
#
#        [[ 41,  41,  41],
#         [ 86,  86,  86],
#         [109, 109, 109],
#         ...,
#         [ 25,  25,  25],
#         [ 80,  80,  80],
#         [ 77,  77,  77]],
#
#        [[ 46,  46,  46],
#         [ 83,  83,  83],
#         [104, 104, 104],
#         ...,
#         [ 75,  75,  75],
#         [129, 129, 129],
#         [125, 125, 125]],
#
#        [[ 40,  40,  40],
#         [ 96,  96,  96],
#         [ 97,  97,  97],
# ...

# %%
plt.imshow(h_img2)

# %%
h_img1.shape
# Out:
# (48, 48, 3)

# %%
h_img2.shape
# Out:
# (48, 48, 3)

# %% [markdown]
# #Angry Images:

# %%
import time

# %%
dataset=[]

# %%
dataset
# Out:
# []

# %%
label=[]

# %%
label
# Out:
# []

# %%
for name in angry_image_names:
  image=cv2.imread(path_angry+"/"+name)
  image=cv2.resize(image,(48,48))
  image=np.array(image)
  dataset.append(image)
  label.append(0)

# %%
len(dataset)
# Out:
# 953

# %%
len(label)
# Out:
# 953

# %% [markdown]
# #Happy Images:

# %%
happy_image_names=os.listdir(path_happy)

# %%
for name in happy_image_names:
  image=cv2.imread(path_happy+"/"+name)
  image=cv2.resize(image,(48,48))
  image=np.array(image)
  dataset.append(image)
  label.append(1)

# %%
len(dataset)
# Out:
# 4068

# %%
len(dataset)
# Out:
# 4068

# %%
type(label)
# Out:
# list

# %%
pd.DataFrame(label).value_counts()
# Out:
# 0
# 1    3115
# 0     953
# Name: count, dtype: int64

# %% [markdown]
# #4)Convert to array:

# %%
type(dataset)
# Out:
# list

# %%
type(label)
# Out:
# list

# %%
ary_dataset=np.array(dataset)

# %%
ary_label=np.array(label)

# %%
type(ary_dataset)
# Out:
# numpy.ndarray

# %%
type(ary_label)
# Out:
# numpy.ndarray

# %% [markdown]
# #5)Feature Scaling:

# %%
ary_dataset.max()
# Out:
# np.uint8(255)

# %%
ary_dataset.min()
# Out:
# np.uint8(0)

# %%
ary_dataset_scale=ary_dataset/255

# %%
ary_dataset_scale.max()
# Out:
# np.float64(1.0)

# %%
ary_dataset_scale.min()
# Out:
# np.float64(0.0)

# %%
test_img1=ary_dataset[1200]

# %%
test_img2=ary_dataset_scale[1200]

# %%
test_img1
# Out:
# array([[[ 43,  43,  43],
#         [ 59,  59,  59],
#         [ 81,  81,  81],
#         ...,
#         [ 77,  77,  77],
#         [ 72,  72,  72],
#         [ 71,  71,  71]],
#
#        [[ 55,  55,  55],
#         [ 73,  73,  73],
#         [ 92,  92,  92],
#         ...,
#         [ 70,  70,  70],
#         [ 78,  78,  78],
#         [ 68,  68,  68]],
#
#        [[ 55,  55,  55],
#         [ 80,  80,  80],
#         [ 99,  99,  99],
#         ...,
#         [ 70,  70,  70],
#         [ 74,  74,  74],
#         [ 93,  93,  93]],
#
#        ...,
#
#        [[  2,   2,   2],
#         [  7,   7,   7],
#         [ 65,  65,  65],
#         ...,
#         [250, 250, 250],
#         [164, 164, 164],
#         [ 50,  50,  50]],
#
#        [[  4,   4,   4],
#         [  0,   0,   0],
#         [ 38,  38,  38],
#         ...,
#         [255, 255, 255],
#         [198, 198, 198],
#         [ 57,  57,  57]],
#
#        [[  3,   3,   3],
#         [  3,   3,   3],
#         [ 16,  16,  16],
# ...

# %%
test_img2
# Out:
# array([[[0.16862745, 0.16862745, 0.16862745],
#         [0.23137255, 0.23137255, 0.23137255],
#         [0.31764706, 0.31764706, 0.31764706],
#         ...,
#         [0.30196078, 0.30196078, 0.30196078],
#         [0.28235294, 0.28235294, 0.28235294],
#         [0.27843137, 0.27843137, 0.27843137]],
#
#        [[0.21568627, 0.21568627, 0.21568627],
#         [0.28627451, 0.28627451, 0.28627451],
#         [0.36078431, 0.36078431, 0.36078431],
#         ...,
#         [0.2745098 , 0.2745098 , 0.2745098 ],
#         [0.30588235, 0.30588235, 0.30588235],
#         [0.26666667, 0.26666667, 0.26666667]],
#
#        [[0.21568627, 0.21568627, 0.21568627],
#         [0.31372549, 0.31372549, 0.31372549],
#         [0.38823529, 0.38823529, 0.38823529],
#         ...,
#         [0.2745098 , 0.2745098 , 0.2745098 ],
#         [0.29019608, 0.29019608, 0.29019608],
#         [0.36470588, 0.36470588, 0.36470588]],
#
#        ...,
#
#        [[0.00784314, 0.00784314, 0.00784314],
# ...

# %%
plt.imshow(test_img1)

# %%
plt.imshow(test_img2)

# %% [markdown]
# #6)Data Seperation:

# %%
X=ary_dataset_scale.copy()

# %%
y=ary_label.copy()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.20)

# %%
X.shape
# Out:
# (4068, 48, 48, 3)

# %%
x_train.shape
# Out:
# (3254, 48, 48, 3)

# %%
x_test.shape
# Out:
# (814, 48, 48, 3)

# %% [markdown]
# #7)Model Building:

# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers  import Input,Conv2D,MaxPooling2D,Flatten,Dense

# %%
x_train.shape
# Out:
# (3254, 48, 48, 3)

# %%
cnn_model=Sequential()

# %%
cnn_model.add(Input(shape=(48,48,3)))

# %% [markdown]
# #First Convolutional Layer:

# %%
cnn_model.add(Conv2D(filters=32,kernel_size=(3,3),strides=(1,1),padding="valid",activation="relu"))

# %%
cnn_model.add(MaxPooling2D(pool_size=(2,2),padding="valid",))

# %% [markdown]
# #Second Convolutional Layer:

# %%
cnn_model.add(Conv2D(filters=32,kernel_size=(3,3),strides=(1,1),padding="valid",activation="relu"))

# %%
cnn_model.add(MaxPooling2D(pool_size=(2,2),padding="valid",))

# %% [markdown]
# #Third Convolutional Layer:

# %%
cnn_model.add(Conv2D(filters=32,kernel_size=(3,3),strides=(1,1),padding="valid",activation="relu"))

# %%
cnn_model.add(MaxPooling2D(pool_size=(2,2),padding="valid",))

# %% [markdown]
# #Fully Connected / Feed Forward Neural Network:

# %%
cnn_model.add(Flatten())

# %%
cnn_model.add(Dense(256,activation="relu"))

# %%
cnn_model.add(Dense(512,activation="relu"))

# %%
cnn_model.add(Dense(1024,activation="relu"))

# %%
cnn_model.add(Dense(512, activation = "relu"))

# %%
cnn_model.add(Dense(256,activation="relu"))

# %%
cnn_model.add(Dense(2,activation="softmax")) #2 outcomes angry,happy

# %% [markdown]
# #8)Summary:

# %%
cnn_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 46, 46, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 23, 23, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 21, 21, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 10, 10, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 32)       │         9,248 │
# ...

# %% [markdown]
# #9)Compile:

# %%
cnn_model.compile(
          optimizer="adam",
          loss="sparse_categorical_crossentropy",
          metrics=["accuracy"])

# %%
cnn_model.fit(x_train,y_train,epochs=15)
# Out:
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - accuracy: 0.7658 - loss: 0.5662
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.7736 - loss: 0.5283
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.7611 - loss: 0.5226
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.7810 - loss: 0.4501
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.7925 - loss: 0.4262
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.8357 - loss: 0.3595
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.8337 - loss: 0.3546
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.8597 - loss: 0.3150
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.8736 - loss: 0.2839
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.8819 - loss: 0.2724
# Epoch 11/15
# ...

# %%
cnn_model.evaluate(x_test,y_test)
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8452 - loss: 0.5577
# [0.5814982056617737, 0.8488943576812744]

# %% [markdown]
# #10)Prediction 1:

# %%
x_test.shape
# Out:
# (814, 48, 48, 3)

# %%
x_test[400]
# Out:
# array([[[0.16470588, 0.16470588, 0.16470588],
#         [0.16078431, 0.16078431, 0.16078431],
#         [0.2       , 0.2       , 0.2       ],
#         ...,
#         [0.90196078, 0.90196078, 0.90196078],
#         [0.65882353, 0.65882353, 0.65882353],
#         [0.39607843, 0.39607843, 0.39607843]],
#
#        [[0.16862745, 0.16862745, 0.16862745],
#         [0.18039216, 0.18039216, 0.18039216],
#         [0.37254902, 0.37254902, 0.37254902],
#         ...,
#         [0.90588235, 0.90588235, 0.90588235],
#         [0.89019608, 0.89019608, 0.89019608],
#         [0.7372549 , 0.7372549 , 0.7372549 ]],
#
#        [[0.16078431, 0.16078431, 0.16078431],
#         [0.24705882, 0.24705882, 0.24705882],
#         [0.63529412, 0.63529412, 0.63529412],
#         ...,
#         [0.89411765, 0.89411765, 0.89411765],
#         [0.94117647, 0.94117647, 0.94117647],
#         [0.88627451, 0.88627451, 0.88627451]],
#
#        ...,
#
#        [[0.22745098, 0.22745098, 0.22745098],
# ...

# %%
x_train.shape
# Out:
# (3254, 48, 48, 3)

# %%
x_test[400].shape
# Out:
# (48, 48, 3)

# %%
x_test[400].reshape((1,)+x_test[400].shape) #convert 3dim to 4dim
# Out:
# array([[[[0.16470588, 0.16470588, 0.16470588],
#          [0.16078431, 0.16078431, 0.16078431],
#          [0.2       , 0.2       , 0.2       ],
#          ...,
#          [0.90196078, 0.90196078, 0.90196078],
#          [0.65882353, 0.65882353, 0.65882353],
#          [0.39607843, 0.39607843, 0.39607843]],
#
#         [[0.16862745, 0.16862745, 0.16862745],
#          [0.18039216, 0.18039216, 0.18039216],
#          [0.37254902, 0.37254902, 0.37254902],
#          ...,
#          [0.90588235, 0.90588235, 0.90588235],
#          [0.89019608, 0.89019608, 0.89019608],
#          [0.7372549 , 0.7372549 , 0.7372549 ]],
#
#         [[0.16078431, 0.16078431, 0.16078431],
#          [0.24705882, 0.24705882, 0.24705882],
#          [0.63529412, 0.63529412, 0.63529412],
#          ...,
#          [0.89411765, 0.89411765, 0.89411765],
#          [0.94117647, 0.94117647, 0.94117647],
#          [0.88627451, 0.88627451, 0.88627451]],
#
#         ...,
#
# ...

# %%
p_img=x_test[400].reshape((1,)+x_test[400].shape)

# %%
p_img
# Out:
# array([[[[0.16470588, 0.16470588, 0.16470588],
#          [0.16078431, 0.16078431, 0.16078431],
#          [0.2       , 0.2       , 0.2       ],
#          ...,
#          [0.90196078, 0.90196078, 0.90196078],
#          [0.65882353, 0.65882353, 0.65882353],
#          [0.39607843, 0.39607843, 0.39607843]],
#
#         [[0.16862745, 0.16862745, 0.16862745],
#          [0.18039216, 0.18039216, 0.18039216],
#          [0.37254902, 0.37254902, 0.37254902],
#          ...,
#          [0.90588235, 0.90588235, 0.90588235],
#          [0.89019608, 0.89019608, 0.89019608],
#          [0.7372549 , 0.7372549 , 0.7372549 ]],
#
#         [[0.16078431, 0.16078431, 0.16078431],
#          [0.24705882, 0.24705882, 0.24705882],
#          [0.63529412, 0.63529412, 0.63529412],
#          ...,
#          [0.89411765, 0.89411765, 0.89411765],
#          [0.94117647, 0.94117647, 0.94117647],
#          [0.88627451, 0.88627451, 0.88627451]],
#
#         ...,
#
# ...

# %%
p_img.shape
# Out:
# (1, 48, 48, 3)

# %%
cnn_model.predict(p_img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# array([[1.7431548e-05, 9.9998260e-01]], dtype=float32)

# %%
np.argmax(cnn_model.predict(p_img))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# np.int64(1)

# %%
y_test[400]
# Out:
# np.int64(1)

# %%
plt.imshow(x_test[400])

# %% [markdown]
# #Prediction 2:

# %%
x_train.shape
# Out:
# (3254, 48, 48, 3)

# %%
x_train[2000]
# Out:
# array([[[0.34901961, 0.34901961, 0.34901961],
#         [0.3254902 , 0.3254902 , 0.3254902 ],
#         [0.39215686, 0.39215686, 0.39215686],
#         ...,
#         [0.07843137, 0.07843137, 0.07843137],
#         [0.12941176, 0.12941176, 0.12941176],
#         [0.15294118, 0.15294118, 0.15294118]],
#
#        [[0.34509804, 0.34509804, 0.34509804],
#         [0.37254902, 0.37254902, 0.37254902],
#         [0.45490196, 0.45490196, 0.45490196],
#         ...,
#         [0.09019608, 0.09019608, 0.09019608],
#         [0.14117647, 0.14117647, 0.14117647],
#         [0.16470588, 0.16470588, 0.16470588]],
#
#        [[0.35686275, 0.35686275, 0.35686275],
#         [0.42352941, 0.42352941, 0.42352941],
#         [0.50196078, 0.50196078, 0.50196078],
#         ...,
#         [0.1372549 , 0.1372549 , 0.1372549 ],
#         [0.15686275, 0.15686275, 0.15686275],
#         [0.17647059, 0.17647059, 0.17647059]],
#
#        ...,
#
#        [[0.07058824, 0.07058824, 0.07058824],
# ...

# %%
x_train[2000].shape
# Out:
# (48, 48, 3)

# %%
p_img2=x_train[2000].reshape((1,)+x_train[2000].shape)

# %%
p_img2.shape
# Out:
# (1, 48, 48, 3)

# %%
cnn_model.predict(p_img2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# array([[6.0489183e-06, 9.9999392e-01]], dtype=float32)

# %%
np.argmax(cnn_model.predict(p_img2))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# np.int64(1)

# %%
y_train[2000]
# Out:
# np.int64(1)

# %%
plt.imshow(x_train[2000])

# %% [markdown]
# #Prediction 3:

# %%
x_train[3252].shape
# Out:
# (48, 48, 3)

# %%
p_img3=x_train[3252].reshape((1,)+x_train[3252].shape)

# %%
p_img3.shape
# Out:
# (1, 48, 48, 3)

# %%
cnn_model.predict(p_img3)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# array([[0.01676697, 0.98323303]], dtype=float32)

# %%
np.argmax(cnn_model.predict(p_img3))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# np.int64(1)

# %%
y_train[3252]
# Out:
# np.int64(1)

# %%
plt.imshow(x_train[3252])

# %% [markdown]
# #11)Conclusion:
# In this project, a CNN model was used to classify facial expressions into Angry and Happy categories. The model was trained using the image dataset and evaluated on test data.
#
# The trained model can also predict the emotion of new images as either angry or happy.
